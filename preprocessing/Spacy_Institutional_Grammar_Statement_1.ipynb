# %%
import spacy
from spacy.lang.en.stop_words import STOP_WORDS
from spacy import displacy
nlp = spacy.load("en_core_web_sm")

# %% [markdown]
# # **Statement 1**

# %%
doc = nlp(u"The Council shall consist of twenty-one members appointed by the Governor as follows: the Commissioner of Agriculture and Markets, the Commissioner of Health, the Commissioner of the Office of Temporary Disability Assistance, the Commissioner of Education, the Commissioner of the Department of Economic Development and the Director of the Office for the Aging")

# %%
print([w.text for w in doc])
# Out:
# ['The', 'Council', 'shall', 'consist', 'of', 'twenty', '-', 'one', 'members', 'appointed', 'by', 'the', 'Governor', 'as', 'follows', ':', 'the', 'Commissioner', 'of', 'Agriculture', 'and', 'Markets', ',', 'the', 'Commissioner', 'of', 'Health', ',', 'the', 'Commissioner', 'of', 'the', 'Office', 'of', 'Temporary', 'Disability', 'Assistance', ',', 'the', 'Commissioner', 'of', 'Education', ',', 'the', 'Commissioner', 'of', 'the', 'Department', 'of', 'Economic', 'Development', 'and', 'the', 'Director', 'of', 'the', 'Office', 'for', 'the', 'Aging']

# %%
for token in doc:
    print(token.text, token.lemma_)
# Out:
# The the
# Council Council
# shall shall
# consist consist
# of of
# twenty twenty
# - -
# one one
# members member
# appointed appoint
# by by
# the the
# Governor Governor
# as as
# follows follow
# : :
# the the
# Commissioner Commissioner
# of of
# Agriculture Agriculture
# and and
# Markets Markets
# , ,
# the the
# Commissioner Commissioner
# of of
# Health Health
# , ,
# the the
# Commissioner Commissioner
# of of
# the the
# Office Office
# of of
# Temporary Temporary
# Disability Disability
# Assistance Assistance
# , ,
# the the
# Commissioner Commissioner
# of of
# Education Education
# , ,
# the the
# Commissioner Commissioner
# of of
# the the
# Department Department
# of of
# Economic Economic
# Development Development
# and and
# the the
# Director Director
# of of
# the the
# Office Office
# for for
# the the
# Aging aging

# %%
import pandas as pd
pst = pd.DataFrame([[w.text,w.tag_,w.pos_, w.dep_] for w in  doc])
pst.columns = ['Text', "Part_of_Speech", "Speech", "Dependency"]
pst
# Out:
#             Text Part_of_Speech Speech Dependency
# 0            The             DT    DET        det
# 1        Council            NNP  PROPN      nsubj
# 2          shall             MD   VERB        aux
# 3        consist             VB   VERB       ROOT
# 4             of             IN    ADP       prep
# 5         twenty             CD    NUM   compound
# 6              -           HYPH  PUNCT      punct
# 7            one             CD    NUM     nummod
# 8        members            NNS   NOUN       pobj
# 9      appointed            VBN   VERB        acl
# 10            by             IN    ADP      agent
# 11           the             DT    DET        det
# 12      Governor            NNP  PROPN       pobj
# 13            as             IN  SCONJ       mark
# 14       follows            VBZ   VERB      advcl
# 15             :              :  PUNCT      punct
# 16           the             DT    DET        det
# 17  Commissioner            NNP  PROPN      appos
# 18            of             IN    ADP       prep
# 19   Agriculture            NNP  PROPN       pobj
# 20           and             CC  CCONJ         cc
# 21       Markets           NNPS  PROPN       conj
# 22             ,              ,  PUNCT      punct
# 23           the             DT    DET        det
# 24  Commissioner            NNP  PROPN       conj
# 25            of             IN    ADP       prep
# 26        Health            NNP  PROPN       pobj
# 27             ,              ,  PUNCT      punct
# 28           the             DT    DET        det
# 29  Commissioner            NNP  PROPN       conj
# 30            of             IN    ADP       prep
# 31           the             DT    DET        det
# 32        Office            NNP  PROPN       pobj
# 33            of             IN    ADP       prep
# 34     Temporary            NNP  PROPN   compound
# 35    Disability            NNP  PROPN   compound
# 36    Assistance            NNP  PROPN       pobj
# 37             ,              ,  PUNCT      punct
# 38           the             DT    DET        det
# 39  Commissioner            NNP  PROPN       conj
# 40            of             IN    ADP       prep
# 41     Education            NNP  PROPN       pobj
# 42             ,              ,  PUNCT      punct
# 43           the             DT    DET        det
# 44  Commissioner            NNP  PROPN       conj
# 45            of             IN    ADP       prep
# 46           the             DT    DET        det
# 47    Department            NNP  PROPN       pobj
# 48            of             IN    ADP       prep
# 49      Economic            NNP  PROPN   compound
# 50   Development            NNP  PROPN       pobj
# 51           and             CC  CCONJ         cc
# 52           the             DT    DET        det
# 53      Director            NNP  PROPN       conj
# 54            of             IN    ADP       prep
# 55           the             DT    DET        det
# 56        Office            NNP  PROPN       pobj
# 57           for             IN    ADP       prep
# 58           the             DT    DET        det
# 59         Aging             NN   NOUN       pobj

# %%
pst_dep_token = pd.DataFrame([w.head.text,w.dep_, w.text] for w in doc)
pst_dep_token.columns = ['Head', "Dependency", "Token"]
pst_dep_token
# Out:
#             Head Dependency         Token
# 0        Council        det           The
# 1        consist      nsubj       Council
# 2        consist        aux         shall
# 3        consist       ROOT       consist
# 4        consist       prep            of
# 5            one   compound        twenty
# 6            one      punct             -
# 7        members     nummod           one
# 8             of       pobj       members
# 9        members        acl     appointed
# 10     appointed      agent            by
# 11      Governor        det           the
# 12            by       pobj      Governor
# 13       follows       mark            as
# 14     appointed      advcl       follows
# 15       members      punct             :
# 16  Commissioner        det           the
# 17       members      appos  Commissioner
# 18  Commissioner       prep            of
# 19            of       pobj   Agriculture
# 20   Agriculture         cc           and
# 21   Agriculture       conj       Markets
# 22  Commissioner      punct             ,
# 23  Commissioner        det           the
# 24  Commissioner       conj  Commissioner
# 25  Commissioner       prep            of
# 26            of       pobj        Health
# 27  Commissioner      punct             ,
# 28  Commissioner        det           the
# 29  Commissioner       conj  Commissioner
# 30  Commissioner       prep            of
# 31        Office        det           the
# 32            of       pobj        Office
# 33        Office       prep            of
# 34    Assistance   compound     Temporary
# 35    Assistance   compound    Disability
# 36            of       pobj    Assistance
# 37  Commissioner      punct             ,
# 38  Commissioner        det           the
# 39  Commissioner       conj  Commissioner
# 40  Commissioner       prep            of
# 41            of       pobj     Education
# 42  Commissioner      punct             ,
# 43  Commissioner        det           the
# 44  Commissioner       conj  Commissioner
# 45  Commissioner       prep            of
# 46    Department        det           the
# 47            of       pobj    Department
# 48    Department       prep            of
# 49   Development   compound      Economic
# 50            of       pobj   Development
# 51  Commissioner         cc           and
# 52      Director        det           the
# 53  Commissioner       conj      Director
# 54      Director       prep            of
# 55        Office        det           the
# 56            of       pobj        Office
# 57      Director       prep           for
# 58         Aging        det           the
# 59           for       pobj         Aging

# %%
head_token_list = []
for w in doc:
  if w.head.text not in head_token_list:
    head_token_list.append(w.head.text)
  else:
    continue

# %%
head_token_list
# Out:
# ['Council',
#  'consist',
#  'one',
#  'members',
#  'of',
#  'appointed',
#  'Governor',
#  'by',
#  'follows',
#  'Commissioner',
#  'Agriculture',
#  'Office',
#  'Assistance',
#  'Department',
#  'Development',
#  'Director',
#  'Aging',
#  'for']

# %%
from spacy import displacy

displacy.render(doc, style='dep', jupyter=True, options={'distance': 90})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="ded8dccef14c43e9be437eeebbf9a3af-0" class="displacy" width="4910" height="542.0" direction="ltr" style="max-width: none; height: 542.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="452.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">The</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="452.0">
#     <tspan class="displacy-word" fill="currentColor" x="140">Council</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="140">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="452.0">
#     <tspan class="displacy-word" fill="currentColor" x="230">shall</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="230">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="452.0">
#     <tspan class="displacy-word" fill="currentColor" x="320">consist</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="320">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="452.0">
#     <tspan class="displacy-word" fill="currentColor" x="410">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="410">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="452.0">
#     <tspan class="displacy-word" fill="currentColor" x="500">twenty-</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="500">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="452.0">
#     <tspan class="displacy-word" fill="currentColor" x="590">one</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="590">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="452.0">
#     <tspan class="displacy-word" fill="currentColor" x="680">members</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="680">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="452.0">
#     <tspan class="displacy-word" fill="currentColor" x="770">appointed</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="770">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="452.0">
#     <tspan class="displacy-word" fill="currentColor" x="860">by</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="860">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="452.0">
#     <tspan class="displacy-word" fill="currentColor" x="950">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="950">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="452.0">
#     <tspan class="displacy-word" fill="currentColor" x="1040">Governor</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1040">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="452.0">
#     <tspan class="displacy-word" fill="currentColor" x="1130">as</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1130">SCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="452.0">
#     <tspan class="displacy-word" fill="currentColor" x="1220">follows:</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1220">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="452.0">
#     <tspan class="displacy-word" fill="currentColor" x="1310">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1310">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="452.0">
#     <tspan class="displacy-word" fill="currentColor" x="1400">Commissioner</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1400">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="452.0">
#     <tspan class="displacy-word" fill="currentColor" x="1490">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1490">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="452.0">
#     <tspan class="displacy-word" fill="currentColor" x="1580">Agriculture</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1580">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="452.0">
#     <tspan class="displacy-word" fill="currentColor" x="1670">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1670">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="452.0">
#     <tspan class="displacy-word" fill="currentColor" x="1760">Markets,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1760">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="452.0">
#     <tspan class="displacy-word" fill="currentColor" x="1850">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1850">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="452.0">
#     <tspan class="displacy-word" fill="currentColor" x="1940">Commissioner</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1940">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="452.0">
#     <tspan class="displacy-word" fill="currentColor" x="2030">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2030">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="452.0">
#     <tspan class="displacy-word" fill="currentColor" x="2120">Health,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2120">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="452.0">
#     <tspan class="displacy-word" fill="currentColor" x="2210">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2210">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="452.0">
#     <tspan class="displacy-word" fill="currentColor" x="2300">Commissioner</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2300">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="452.0">
#     <tspan class="displacy-word" fill="currentColor" x="2390">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2390">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="452.0">
#     <tspan class="displacy-word" fill="currentColor" x="2480">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2480">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="452.0">
#     <tspan class="displacy-word" fill="currentColor" x="2570">Office</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2570">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="452.0">
#     <tspan class="displacy-word" fill="currentColor" x="2660">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2660">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="452.0">
#     <tspan class="displacy-word" fill="currentColor" x="2750">Temporary</tspan>
#     <tspan class="displacy-tag" dy="2em"

# %% [markdown]
# #### Extracting the Root of the Sentence

# %% [markdown]
# ##### *Parsing the Tree*

# %%
for token in doc:
    print(token.text, token.dep_, token.head.text, token.head.pos_,
            [child for child in token.children])
# Out:
# The det Council PROPN []
# Council nsubj consist VERB [The]
# shall aux consist VERB []
# consist ROOT consist VERB [Council, shall, of]
# of prep consist VERB [members]
# twenty compound one NUM []
# - punct one NUM []
# one nummod members NOUN [twenty, -]
# members pobj of ADP [one, appointed, :, Commissioner]
# appointed acl members NOUN [by, follows]
# by agent appointed VERB [Governor]
# the det Governor PROPN []
# Governor pobj by ADP [the]
# as mark follows VERB []
# follows advcl appointed VERB [as]
# : punct members NOUN []
# the det Commissioner PROPN []
# Commissioner appos members NOUN [the, of, ,, Commissioner]
# of prep Commissioner PROPN [Agriculture]
# Agriculture pobj of ADP [and, Markets]
# and cc Agriculture PROPN []
# Markets conj Agriculture PROPN []
# , punct Commissioner PROPN []
# the det Commissioner PROPN []
# Commissioner conj Commissioner PROPN [the, of, ,, Commissioner]
# of prep Commissioner PROPN [Health]
# Health pobj of ADP []
# , punct Commissioner PROPN []
# the det Commissioner PROPN []
# Commissioner conj Commissioner PROPN [the, of, ,, Commissioner]
# of prep Commissioner PROPN [Office]
# the det Office PROPN []
# Office pobj of ADP [the, of]
# of prep Office PROPN [Assistance]
# Temporary compound Assistance PROPN []
# Disability compound Assistance PROPN []
# Assistance pobj of ADP [Temporary, Disability]
# , punct Commissioner PROPN []
# the det Commissioner PROPN []
# Commissioner conj Commissioner PROPN [the, of, ,, Commissioner]
# of prep Commissioner PROPN [Education]
# Education pobj of ADP []
# , punct Commissioner PROPN []
# the det Commissioner PROPN []
# Commissioner conj Commissioner PROPN [the, of, and, Director]
# of prep Commissioner PROPN [Department]
# the det Department PROPN []
# Department pobj of ADP [the, of]
# of prep Department PROPN [Development]
# Economic compound Development PROPN []
# Development pobj of ADP [Economic]
# and cc Commissioner PROPN []
# the det Director PROPN []
# Director conj Commissioner PROPN [the, of, for]
# of prep Director PROPN [Office]
# the det Office PROPN []
# Office pobj of ADP [the]
# for prep Director PROPN [Aging]
# the det Aging NOUN []
# Aging pobj for ADP [the]

# %%
lefts = []
rights = []
for w in doc:
  if w.dep_ == "ROOT":
    i = w.i
    for lc in doc[i].lefts:
      if lc.n_lefts >= 1 :
        for lcc in lc.lefts:
          lefts.append(lcc.text)
        lefts.append(lc.text)
      else:
        lefts.append(lc.text)
    lefts.append(doc[i])
    for rc in doc[i].rights:
      if rc.n_rights >= 1 :
        lefts.append(rc.text)
part_one = " ".join([str(token) for token in lefts])

# %%
part_one
# Out:
# 'The Council shall consist of'

# %% [markdown]
# #### Extracting the Other Parts of Sentences
# ##### Method 1: Using the noun chunks

# %%
noun_chunk_token = pd.DataFrame([chunk.text, chunk.root.text, chunk.root.dep_,
            chunk.root.head.text] for chunk in doc.noun_chunks)
noun_chunk_token.columns = ["Noun", "Root", "Dependency", "Head of Chunk"]
noun_chunk_token
# Out:
#                                Noun          Root Dependency Head of Chunk
# 0                       The Council       Council      nsubj       consist
# 1                twenty-one members       members       pobj            of
# 2                      the Governor      Governor       pobj            by
# 3                  the Commissioner  Commissioner      appos       members
# 4                       Agriculture   Agriculture       pobj            of
# 5                           Markets       Markets       conj   Agriculture
# 6                  the Commissioner  Commissioner       conj  Commissioner
# 7                            Health        Health       pobj            of
# 8                  the Commissioner  Commissioner       conj  Commissioner
# 9                        the Office        Office       pobj            of
# 10  Temporary Disability Assistance    Assistance       pobj            of
# 11                 the Commissioner  Commissioner       conj  Commissioner
# 12                        Education     Education       pobj            of
# 13                 the Commissioner  Commissioner       conj  Commissioner
# 14                   the Department    Department       pobj            of
# 15             Economic Development   Development       pobj            of
# 16                     the Director      Director       conj  Commissioner
# 17                       the Office        Office       pobj            of
# 18                        the Aging         Aging       pobj           for

# %%
for chunk in doc.noun_chunks:
  if str(chunk.text) in part_one:
    continue
  else:
    print([left for left in chunk.lefts], chunk,[right for right in chunk.rights] )
# Out:
# [] twenty-one members [appointed, :, Commissioner]
# [] the Governor []
# [] the Commissioner [of, ,, Commissioner]
# [] Agriculture [and, Markets]
# [] Markets []
# [] the Commissioner [of, ,, Commissioner]
# [] Health []
# [] the Commissioner [of, ,, Commissioner]
# [] the Office [of]
# [] Temporary Disability Assistance []
# [] the Commissioner [of, ,, Commissioner]
# [] Education []
# [] the Commissioner [of, and, Director]
# [] the Department [of]
# [] Economic Development []
# [] the Director [of, for]
# [] the Office []
# [] the Aging []

# %%
sentences = []

def inorderTraversal(chunk):
    res = []
    for left in chunk.lefts:
      res = inorderTraversal(left)
    res.append(str(chunk.text))
    for right in chunk.rights:
      if (right.dep_ == "conj") & (right.pos_ == "PROPN") & (right.n_rights >= 1):
        continue
      if (right.dep_ == "appos") & (right.pos_ == "PROPN") & (right.n_rights >= 1):
        continue
      if (right.dep_ == "cc") & (right.pos_ == "CCONJ") & (right.head.dep_ == "conj") & (right.head.pos_ == "PROPN"):
        continue
      if (right.dep_ == "advcl") & (right.pos_ == "VERB"):
        continue
      if (right.dep_ == "PUNCT"):
        continue
      else:
        res = res + inorderTraversal(right)
    return res


for chunk in doc.noun_chunks:
  # The chunks dont have a left tree so there is no left list
  if (chunk.root.dep_ == "conj") & (chunk.root.pos_ =="PROPN") & (chunk.root.n_rights >= 1): # Only selecting the commisoner and directors 
    sentences.append(part_one + " " + " ".join(inorderTraversal(chunk)) )      
  if (chunk.root.dep_ == "appos") & (chunk.root.pos_ =="PROPN") & (chunk.root.n_rights >= 1): # Only selecting the commisoner and directors 
    sentences.append(part_one + " " + " ".join(inorderTraversal(chunk)) )   
  if (chunk.root.dep_ == "pobj") & (chunk.root.pos_ =="NOUN") & (chunk.root.n_rights >= 1): # Only selecting the commisoner and directors 
    sentences.append(part_one + " " + " ".join(inorderTraversal(chunk)) )

# %%
import re
for i in sentences:
  new = re.sub(r'[^a-zA-Z0-9\s-]', '',i)
  print(new)
# Out:
# The Council shall consist of twenty-one members appointed by the Governor
# The Council shall consist of the Commissioner of Agriculture and Markets
# The Council shall consist of the Commissioner of Health
# The Council shall consist of the Commissioner of the Office of Disability Assistance
# The Council shall consist of the Commissioner of Education
# The Council shall consist of the Commissioner of the Department of Economic Development
# The Council shall consist of the Director of the Office for the Aging
