# %%
import spacy
from spacy.lang.en.stop_words import STOP_WORDS
from spacy import displacy
nlp = spacy.load("en_core_web_sm")
from textacy import preprocessing

# %% [markdown]
# # **Statement 2**

# %%
statement = """5. The Council shall: (a) develop and recommend a food policy for the State which recognizes that it is in the best interests of the State to ensure the availability of an adequate supply of affordable, fresh, nutritious food to its residents; (b) develop and recommend State policies to expand agricultural production, including locally-grown and organically-grown food; (c) develop and recommend a strategic plan for implementation of the State food policy, including benchmarks and criteria for measuring progress in achieving State food policy objectives; and (d) offer comments on State regulations, legislation and budget proposals in the area of food policy, to ensure a coordinated and comprehensive inter-agency approach to food policy issues."""
import re
statement1 = re.sub("\([a-z]\)|([0-9]\.)","", statement)
statement = preprocessing.normalize_whitespace(statement1)
statement
# Out:
# 'The Council shall: develop and recommend a food policy for the State which recognizes that it is in the best interests of the State to ensure the availability of an adequate supply of affordable, fresh, nutritious food to its residents; develop and recommend State policies to expand agricultural production, including locally-grown and organically-grown food; develop and recommend a strategic plan for implementation of the State food policy, including benchmarks and criteria for measuring progress in achieving State food policy objectives; and offer comments on State regulations, legislation and budget proposals in the area of food policy, to ensure a coordinated and comprehensive inter-agency approach to food policy issues.'

# %%
doc = nlp(u"The Council shall: develop and recommend a food policy for the State which recognizes that it is in the best interests of the State to ensure the availability of an adequate supply of affordable, fresh, nutritious food to its residents; develop and recommend State policies to expand agricultural production, including locally-grown and organically-grown food; develop and recommend a strategic plan for implementation of the State food policy, including benchmarks and criteria for measuring progress in achieving State food policy objectives; and offer comments on State regulations, legislation and budget proposals in the area of food policy, to ensure a coordinated and comprehensive inter-agency approach to food policy issues.")

# %%
print([w.text for w in doc])
# Out:
# ['The', 'Council', 'shall', ':', 'develop', 'and', 'recommend', 'a', 'food', 'policy', 'for', 'the', 'State', 'which', 'recognizes', 'that', 'it', 'is', 'in', 'the', 'best', 'interests', 'of', 'the', 'State', 'to', 'ensure', 'the', 'availability', 'of', 'an', 'adequate', 'supply', 'of', 'affordable', ',', 'fresh', ',', 'nutritious', 'food', 'to', 'its', 'residents', ';', 'develop', 'and', 'recommend', 'State', 'policies', 'to', 'expand', 'agricultural', 'production', ',', 'including', 'locally', '-', 'grown', 'and', 'organically', '-', 'grown', 'food', ';', 'develop', 'and', 'recommend', 'a', 'strategic', 'plan', 'for', 'implementation', 'of', 'the', 'State', 'food', 'policy', ',', 'including', 'benchmarks', 'and', 'criteria', 'for', 'measuring', 'progress', 'in', 'achieving', 'State', 'food', 'policy', 'objectives', ';', 'and', 'offer', 'comments', 'on', 'State', 'regulations', ',', 'legislation', 'and', 'budget', 'proposals', 'in', 'the', 'area', 'of', 'food', 'policy', ',', 'to', 'ensure', 'a', 'coordinated', 'and', 'comprehensive', 'inter', '-', 'agency', 'approach', 'to', 'food', 'policy', 'issues', '.']

# %%
import pandas as pd
pst = pd.DataFrame([[w.text,w.tag_,w.pos_, w.dep_] for w in  doc])
pst.columns = ['Text', "Part_of_Speech", "Speech", "Dependency"]
pst.to_csv("Sentence 2 Tagging.csv")

# %% [markdown]
# #### Extracting the Root of the Sentence

# %% [markdown]
# ##### *Parsing the Tree*

# %%
for token in doc:
    print(token.text, token.dep_, token.head.text, token.head.pos_,
            [child for child in token.children])
# Out:
# The det Council PROPN []
# Council nsubj develop VERB [The]
# shall aux develop VERB []
# : punct develop VERB []
# develop ROOT develop VERB [Council, shall, :, and, recommend, ;, develop, .]
# and cc develop VERB []
# recommend conj develop VERB [policy]
# a det policy NOUN []
# food compound policy NOUN []
# policy dobj recommend VERB [a, food, for, recognizes]
# for prep policy NOUN [State]
# the det State NOUN []
# State pobj for ADP [the]
# which nsubj recognizes VERB []
# recognizes relcl policy NOUN [which, is]
# that mark is AUX []
# it nsubj is AUX []
# is ccomp recognizes VERB [that, it, in, ensure]
# in prep is AUX [interests]
# the det interests NOUN []
# best amod interests NOUN []
# interests pobj in ADP [the, best, of]
# of prep interests NOUN [State]
# the det State PROPN []
# State pobj of ADP [the]
# to aux ensure VERB []
# ensure xcomp is AUX [to, availability]
# the det availability NOUN []
# availability dobj ensure VERB [the, of, to]
# of prep availability NOUN [supply]
# an det supply NOUN []
# adequate amod supply NOUN []
# supply pobj of ADP [an, adequate, of]
# of prep supply NOUN [food]
# affordable amod food NOUN []
# , punct food NOUN []
# fresh amod food NOUN []
# , punct food NOUN []
# nutritious amod food NOUN []
# food pobj of ADP [affordable, ,, fresh, ,, nutritious]
# to prep availability NOUN [residents]
# its poss residents NOUN []
# residents pobj to ADP [its]
# ; punct develop VERB []
# develop conj develop VERB [and, recommend, ;, develop]
# and cc develop VERB []
# recommend conj develop VERB [policies, expand]
# State compound policies NOUN []
# policies dobj recommend VERB [State]
# to aux expand VERB []
# expand xcomp recommend VERB [to, production, including]
# agricultural amod production NOUN []
# production dobj expand VERB [agricultural, ,]
# , punct production NOUN []
# including prep expand VERB [food]
# locally advmod grown ADJ []
# - punct grown ADJ []
# grown amod food NOUN [locally, -, and, grown]
# and cc grown ADJ []
# organically advmod grown VERB []
# - punct grown VERB []
# grown conj grown ADJ [organically, -]
# food pobj including VERB [grown]
# ; punct develop VERB []
# develop conj develop VERB [and, recommend, ;, and, offer]
# and cc develop VERB []
# recommend conj develop VERB [plan]
# a det plan NOUN []
# strategic amod plan NOUN []
# plan dobj recommend VERB [a, strategic, for]
# for prep plan NOUN [implementation]
# implementation pobj for ADP [of]
# of prep implementation NOUN [policy]
# the det policy NOUN []
# State compound policy NOUN []
# food compound policy NOUN []
# policy pobj of ADP [the, State, food, ,, including]
# , punct policy NOUN []
# including prep policy NOUN [benchmarks]
# benchmarks pobj including VERB [and, criteria, for]
# and cc benchmarks NOUN []
# criteria conj benchmarks NOUN []
# for prep benchmarks NOUN [measuring]
# measuring pcomp for ADP [progress]
# progress dobj measuring VERB [in]
# in prep progress NOUN [achieving]
# achieving pcomp in ADP [objectives]
# State compound objectives NOUN []
# food compound policy NOUN []
# policy compound objectives NOUN [food]
# objectives dobj achieving VERB [State, policy]
# ; punct develop VERB []
# and cc develop VERB []
# offer conj develop VERB [comments, ,, ensure]
# comments dobj offer VERB [on]
# on prep comments NOUN [regulations]
# State compound regulations NOUN []
# regulations pobj on ADP [State, ,, legislation, in]
# , punct regulations NOUN []
# legislation conj regulations NOUN [and, proposals]
# and cc legislation NOUN []
# budget compound proposals NOUN []
# proposals conj legislation NOUN [budget]
# in prep regulations NOUN [area]
# the det area NOUN []
# area pobj in ADP [the, of]
# of prep area NOUN [policy]
# food compound policy NOUN []
# policy pobj of ADP [food]
# , punct offer VERB []
# to aux ensure VERB []
# ensure advcl offer VERB [to, approach]
# a det approach NOUN []
# coordinated amod approach NOUN [and, comprehensive]
# and cc coordinated ADJ []
# comprehensive conj coordinated ADJ []
# inter dep - ADJ []
# - dep agency ADJ [inter]
# agency amod approach NOUN [-]
# approach dobj ensure VERB [a, coordinated, agency, to]
# to prep approach NOUN [issues]
# food compound policy NOUN []
# policy compound issues NOUN [food]
# issues pobj to ADP [policy]
# . punct develop VERB []

# %%
lefts = []
rights = []
for w in doc:
  if w.dep_ == "ROOT":
    i = w.i
    for lc in doc[i].lefts:
      if lc.n_lefts >= 1 :
        for lcc in lc.lefts:
          lefts.append(lcc.text)
        lefts.append(lc.text)
      else:
        lefts.append(lc.text)
    for rc in doc[i].rights:
        if rc.n_rights >= 1 :
            if rc.dep_ == "CC":
                continue
            if (rc.dep_ == "CONJ") & (rc.pos_ == "VERB"):
                continue
            else:
                rights.append(rc.text)
part_one = " ".join([str(token) for token in lefts])

# %%
part_one = re.sub(r'[^a-zA-Z0-9\s-]', '',part_one)
part_one
# Out:
# 'The Council shall '

# %%
def inorderTraversal(token, root):
    res = []
    for left in token.lefts:
      res = inorderTraversal(left,root)
    res.append(str(token.text))
    for right in token.rights:
      if right.text == root :
        continue
      if (right.dep_ == "PUNCT"):
        continue
      else:
        res = res + inorderTraversal(right,root)
    return res

for token in doc:
    if token.dep_ == "ROOT":
        root = token.text
sentence = []
for token in doc:
    if (token.text == root):
        sentence.append(part_one  + " ".join(inorderTraversal(token, root)))

# %%
import re
for i in sentence:
    new = re.sub(r'[^a-zA-Z0-9\s-]', '',i)
    new = preprocessing.normalize_whitespace(new)
    print(new)
    print("\n")
# Out:
# The Council shall develop and recommend food policy for the State which recognizes it is in best interests of the State to ensure the availability of adequate supply of nutritious food to its residents
#
#
# The Council shall develop and recommend State policies to expand agricultural production including - grown and - grown food
#
#
# The Council shall develop and recommend strategic plan for implementation of food policy including benchmarks and criteria for measuring progress in achieving food policy objectives and offer comments on State regulations legislation and budget proposals in the area of food policy to ensure inter - agency approach to food policy issues

# %% [markdown]
# ## Statement 1

# %%
doc = nlp(u"The Council shall consist of twenty-one members appointed by the Governor as follows: the Commissioner of Agriculture and Markets, the Commissioner of Health, the Commissioner of the Office of Temporary Disability Assistance, the Commissioner of Education, the Commissioner of the Department of Economic Development and the Director of the Office for the Aging")

# %%
import pandas as pd
pst = pd.DataFrame([[w.text,w.tag_,w.pos_, w.dep_] for w in  doc])
pst.columns = ['Text', "Part_of_Speech", "Speech", "Dependency"]
pst
# Out:
#             Text Part_of_Speech Speech Dependency
# 0            The             DT    DET        det
# 1        Council            NNP  PROPN      nsubj
# 2          shall             MD   VERB        aux
# 3        consist             VB   VERB       ROOT
# 4             of             IN    ADP       prep
# 5         twenty             CD    NUM   compound
# 6              -           HYPH  PUNCT      punct
# 7            one             CD    NUM     nummod
# 8        members            NNS   NOUN       pobj
# 9      appointed            VBN   VERB        acl
# 10            by             IN    ADP      agent
# 11           the             DT    DET        det
# 12      Governor            NNP  PROPN       pobj
# 13            as             IN  SCONJ       mark
# 14       follows            VBZ   VERB      advcl
# 15             :              :  PUNCT      punct
# 16           the             DT    DET        det
# 17  Commissioner            NNP  PROPN      appos
# 18            of             IN    ADP       prep
# 19   Agriculture            NNP  PROPN       pobj
# 20           and             CC  CCONJ         cc
# 21       Markets           NNPS  PROPN       conj
# 22             ,              ,  PUNCT      punct
# 23           the             DT    DET        det
# 24  Commissioner            NNP  PROPN       conj
# 25            of             IN    ADP       prep
# 26        Health            NNP  PROPN       pobj
# 27             ,              ,  PUNCT      punct
# 28           the             DT    DET        det
# 29  Commissioner            NNP  PROPN       conj
# 30            of             IN    ADP       prep
# 31           the             DT    DET        det
# 32        Office            NNP  PROPN       pobj
# 33            of             IN    ADP       prep
# 34     Temporary            NNP  PROPN   compound
# 35    Disability            NNP  PROPN   compound
# 36    Assistance            NNP  PROPN       pobj
# 37             ,              ,  PUNCT      punct
# 38           the             DT    DET        det
# 39  Commissioner            NNP  PROPN       conj
# 40            of             IN    ADP       prep
# 41     Education            NNP  PROPN       pobj
# 42             ,              ,  PUNCT      punct
# 43           the             DT    DET        det
# 44  Commissioner            NNP  PROPN       conj
# 45            of             IN    ADP       prep
# 46           the             DT    DET        det
# 47    Department            NNP  PROPN       pobj
# 48            of             IN    ADP       prep
# 49      Economic            NNP  PROPN   compound
# 50   Development            NNP  PROPN       pobj
# 51           and             CC  CCONJ         cc
# 52           the             DT    DET        det
# 53      Director            NNP  PROPN       conj
# 54            of             IN    ADP       prep
# 55           the             DT    DET        det
# 56        Office            NNP  PROPN       pobj
# 57           for             IN    ADP       prep
# 58           the             DT    DET        det
# 59         Aging             NN   NOUN       pobj

# %%
lefts = []
rights = []
for w in doc:
  if w.dep_ == "ROOT":
    i = w.i
    for lc in doc[i].lefts:
      if lc.n_lefts >= 1 :
        for lcc in lc.lefts:
          lefts.append(lcc.text)
        lefts.append(lc.text)
      else:
        lefts.append(lc.text)
    lefts.append(doc[i])
    for rc in doc[i].rights:
      if rc.n_rights >= 1 :
        lefts.append(rc.text)
part_one = " ".join([str(token) for token in lefts])

# %%
sentences = []

def inorderTraversal(chunk):
    res = []
    for left in chunk.lefts:
      res = inorderTraversal(left)
    res.append(str(chunk.text))
    for right in chunk.rights:
      if (right.dep_ == "conj") & (right.pos_ == "PROPN") & (right.n_rights >= 1):
        continue
      if (right.dep_ == "appos") & (right.pos_ == "PROPN") & (right.n_rights >= 1):
        continue
      if (right.dep_ == "cc") & (right.pos_ == "CCONJ") & (right.head.dep_ == "conj") & (right.head.pos_ == "PROPN"):
        continue
      if (right.dep_ == "advcl") & (right.pos_ == "VERB"):
        continue
      if (right.dep_ == "PUNCT"):
        continue
      else:
        res = res + inorderTraversal(right)
    return res


for chunk in doc.noun_chunks:
  # The chunks dont have a left tree so there is no left list
  if (chunk.root.dep_ == "conj") & (chunk.root.pos_ =="PROPN") & (chunk.root.n_rights >= 1): # Only selecting the commisoner and directors 
    sentences.append(part_one + " " + " ".join(inorderTraversal(chunk)) )      
  if (chunk.root.dep_ == "appos") & (chunk.root.pos_ =="PROPN") & (chunk.root.n_rights >= 1): # Only selecting the commisoner and directors 
    sentences.append(part_one + " " + " ".join(inorderTraversal(chunk)) )   
  if (chunk.root.dep_ == "pobj") & (chunk.root.pos_ =="NOUN") & (chunk.root.n_rights >= 1): # Only selecting the commisoner and directors 
    sentences.append(part_one + " " + " ".join(inorderTraversal(chunk)) )

# %%
import re
for i in sentences:
  new = re.sub(r'[^a-zA-Z0-9\s-]', '',i)
  print(new)
# Out:
# The Council shall consist of twenty-one members appointed by the Governor
# The Council shall consist of the Commissioner of Agriculture and Markets
# The Council shall consist of the Commissioner of Health
# The Council shall consist of the Commissioner of the Office of Disability Assistance
# The Council shall consist of the Commissioner of Education
# The Council shall consist of the Commissioner of the Department of Economic Development
# The Council shall consist of the Director of the Office for the Aging

# %% [markdown]
# ### Statement 3

# %%
statement = """The Council shall issue a written report on the first day of December each year on: (a) the activities of the Council during the preceding year; (b) recommended food policies for the State; (c) recommended changes to the strategic plan; (d) an account of the progress made in achieving the goals of the Council; and (e) actions which are necessary to implement the recommendations of the Council and effectuate the purposes of this Order.
"""
import re
statement1 = re.sub("\([a-z]\)|[0-9]\)|\n","", statement)
statement = preprocessing.normalize_whitespace(statement1)
statement
# Out:
# 'The Council shall issue a written report on the first day of December each year on: the activities of the Council during the preceding year; recommended food policies for the State; recommended changes to the strategic plan; an account of the progress made in achieving the goals of the Council; and actions which are necessary to implement the recommendations of the Council and effectuate the purposes of this Order.'

# %%
doc = nlp(statement)

# %%
doc
# Out:
# The Council shall issue a written report on the first day of December each year on: the activities of the Council during the preceding year; recommended food policies for the State; recommended changes to the strategic plan; an account of the progress made in achieving the goals of the Council; and actions which are necessary to implement the recommendations of the Council and effectuate the purposes of this Order.

# %%
from spacy import displacy

displacy.render(doc, style='dep', jupyter=True, options={'distance': 90})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="ae46c306051a472ab9e264702e20bedc-0" class="displacy" width="6260" height="677.0" direction="ltr" style="max-width: none; height: 677.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="587.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">The</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="587.0">
#     <tspan class="displacy-word" fill="currentColor" x="140">Council</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="140">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="587.0">
#     <tspan class="displacy-word" fill="currentColor" x="230">shall</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="230">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="587.0">
#     <tspan class="displacy-word" fill="currentColor" x="320">issue</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="320">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="587.0">
#     <tspan class="displacy-word" fill="currentColor" x="410">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="410">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="587.0">
#     <tspan class="displacy-word" fill="currentColor" x="500">written</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="500">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="587.0">
#     <tspan class="displacy-word" fill="currentColor" x="590">report</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="590">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="587.0">
#     <tspan class="displacy-word" fill="currentColor" x="680">on</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="680">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="587.0">
#     <tspan class="displacy-word" fill="currentColor" x="770">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="770">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="587.0">
#     <tspan class="displacy-word" fill="currentColor" x="860">first</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="860">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="587.0">
#     <tspan class="displacy-word" fill="currentColor" x="950">day</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="950">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="587.0">
#     <tspan class="displacy-word" fill="currentColor" x="1040">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1040">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="587.0">
#     <tspan class="displacy-word" fill="currentColor" x="1130">December</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1130">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="587.0">
#     <tspan class="displacy-word" fill="currentColor" x="1220">each</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1220">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="587.0">
#     <tspan class="displacy-word" fill="currentColor" x="1310">year</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1310">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="587.0">
#     <tspan class="displacy-word" fill="currentColor" x="1400">on:</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1400">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="587.0">
#     <tspan class="displacy-word" fill="currentColor" x="1490">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1490">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="587.0">
#     <tspan class="displacy-word" fill="currentColor" x="1580">activities</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1580">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="587.0">
#     <tspan class="displacy-word" fill="currentColor" x="1670">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1670">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="587.0">
#     <tspan class="displacy-word" fill="currentColor" x="1760">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1760">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="587.0">
#     <tspan class="displacy-word" fill="currentColor" x="1850">Council</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1850">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="587.0">
#     <tspan class="displacy-word" fill="currentColor" x="1940">during</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1940">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="587.0">
#     <tspan class="displacy-word" fill="currentColor" x="2030">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2030">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="587.0">
#     <tspan class="displacy-word" fill="currentColor" x="2120">preceding</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2120">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="587.0">
#     <tspan class="displacy-word" fill="currentColor" x="2210">year;</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2210">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="587.0">
#     <tspan class="displacy-word" fill="currentColor" x="2300">recommended</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2300">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="587.0">
#     <tspan class="displacy-word" fill="currentColor" x="2390">food</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2390">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="587.0">
#     <tspan class="displacy-word" fill="currentColor" x="2480">policies</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2480">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="587.0">
#     <tspan class="displacy-word" fill="currentColor" x="2570">for</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2570">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="587.0">
#     <tspan class="displacy-word" fill="currentColor" x="2660">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2660">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="587.0">
#     <tspan class="displacy-word" fill="currentColor" x="2750">State;</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2750">N

# %%
part_one = "The Council shall issue a written report on the first day of December each year on"

# %%
lefts = []
rights = []
for w in doc:
  if w.dep_ == "ROOT":
    i = w.i
    for lc in doc[i].lefts:
      if lc.n_lefts >= 1 :
        for lcc in lc.lefts:
          lefts.append(lcc.text)
        lefts.append(lc.text)
      else:
        lefts.append(lc.text)
    for rc in doc[i].rights:
        if rc.n_rights >= 1 :
            if (rc.dep_ == "dobj") & (rc.pos_ == "NOUN") & (rc.n_rights >= 1):
                continue 
            if (rc.dep_ == "advcl") & (rc.pos_ == "VERB")& (rc.n_rights >= 1):
                continue
            if (rc.dep_ == "conj") & (rc.pos_ == "VERB")& (rc.n_rights >= 1):
                continue         
            if (rc.dep_ == "npadvmod") & (rc.pos_ == "NOUN")& (rc.n_rights >= 1):
                continue
            else:
                rights.append(rc.text)
part_one = " ".join([str(token) for token in lefts])

# %%
part_one
# Out:
# 'The Council shall'

# %%
def inorderTraversal(token):
    res = []
    for left in token.lefts:
      res = inorderTraversal(left)
    res.append(str(token.text))
    for right in token.rights:
        res = res + inorderTraversal(right)
    return res

sentence = []
for token in doc:
     if token.dep_ == "ROOT":
        print(token)
        for tokens in token.rights:
            if (tokens.dep_ == "dobj") & (tokens.pos_ == "NOUN") & (tokens.n_rights >= 1):
                sentence.append(part_one + " " + " ".join(inorderTraversal(tokens)) ) 
            if (tokens.dep_ == "advcl") & (tokens.pos_ == "VERB"):
                sentence.append(part_one + " " + " ".join(inorderTraversal(tokens)) ) 
            if (tokens.dep_ == "conj") & (tokens.pos_ == "VERB"):
                sentence.append(part_one + " " + " ".join(inorderTraversal(tokens)) )             
            if (tokens.dep_ == "npadvmod") & (tokens.pos_ == "NOUN"):
                sentence.append(part_one + " " + " ".join(inorderTraversal(tokens)) )
# Out:
# issue

# %%
sentence
# Out:
# ['The Council shall issue a written report on the first day of December each year on the activities of the Council during preceding year ;',
#  'The Council shall issue a written report on the first day of December each year on recommended food policies for the State',
#  'The Council shall issue a written report on the first day of December each year on recommended changes to strategic plan',
#  'The Council shall issue a written report on the first day of December each year on an account of the progress made in achieving the goals of the Council ; and actions which are necessary to implement the recommendations of the Council and effectuate the purposes of this Order']

# %%
import re
for i in sentence:
    print(i)
# Out:
# The Council shall issue a written report on the first day of December each year onshall issue written report on first day of December each year on : the activities of the Council during preceding year ; recommended food policies for the State ; recommended changes to strategic plan ; an account of the progress made in achieving the goals of the Council ; and actions which are necessary to implement the recommendations of the Council and effectuate the purposes of this Order .

# %% [markdown]
# # Statement 4

# %%
statement = """The responsibilities of the Division of Public Health's representative include: 1) serving as staff person
and recording secretary to the Commission, 2) informing the Commission of the progress and conditions
in the area of nutrition and food access, 3) advising the Commission on matters pertaining to food and
nutrition when requested, 4) cooperating with the Commission in such matters as may be requested, 5)
administering the Commission's budget and 6) providing additional support services as needed."""
statement
# Out:
# "The responsibilities of the Division of Public Health's representative include: 1) serving as staff person\nand recording secretary to the Commission, 2) informing the Commission of the progress and conditions\nin the area of nutrition and food access, 3) advising the Commission on matters pertaining to food and\nnutrition when requested, 4) cooperating with the Commission in such matters as may be requested, 5)\nadministering the Commission's budget and 6) providing additional support services as needed."

# %%
import re
statement1 = re.sub("\([a-z]\)|([0-9]\.)|([0-9]\))","", statement)
statement2 = re.sub("\n"," ",statement1)
statement = preprocessing.normalize_whitespace(statement2)
statement
# Out:
# "The responsibilities of the Division of Public Health's representative include: serving as staff person and recording secretary to the Commission, informing the Commission of the progress and conditions in the area of nutrition and food access, advising the Commission on matters pertaining to food and nutrition when requested, cooperating with the Commission in such matters as may be requested, administering the Commission's budget and providing additional support services as needed."

# %%
doc = nlp(u"The responsibilities of the Division of Public Health's representative include: serving as staff person and recording secretary to the Commission, informing the Commission of the progress and conditions in the area of nutrition and food access, advising the Commission on matters pertaining to food and nutrition when requested, cooperating with the Commission in such matters as may be requested, administering the Commission's budget and providing additional support services as needed.")
print([w.text for w in doc])
# Out:
# ['The', 'responsibilities', 'of', 'the', 'Division', 'of', 'Public', 'Health', "'s", 'representative', 'include', ':', 'serving', 'as', 'staff', 'person', 'and', 'recording', 'secretary', 'to', 'the', 'Commission', ',', 'informing', 'the', 'Commission', 'of', 'the', 'progress', 'and', 'conditions', 'in', 'the', 'area', 'of', 'nutrition', 'and', 'food', 'access', ',', 'advising', 'the', 'Commission', 'on', 'matters', 'pertaining', 'to', 'food', 'and', 'nutrition', 'when', 'requested', ',', 'cooperating', 'with', 'the', 'Commission', 'in', 'such', 'matters', 'as', 'may', 'be', 'requested', ',', 'administering', 'the', 'Commission', "'s", 'budget', 'and', 'providing', 'additional', 'support', 'services', 'as', 'needed', '.']

# %%
import pandas as pd
pst = pd.DataFrame([[w.text,w.tag_,w.pos_, w.dep_] for w in  doc])
pst.columns = ['Text', "Part_of_Speech", "Speech", "Dependency"]
pst.to_csv("Sentence 3 Tagging.csv")

# %%
from spacy import displacy

displacy.render(doc, style='dep', jupyter=True, options={'distance': 90})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="53615f97b33b4f1fabe308b9229e1cf2-0" class="displacy" width="6530" height="677.0" direction="ltr" style="max-width: none; height: 677.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="587.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">The</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="587.0">
#     <tspan class="displacy-word" fill="currentColor" x="140">responsibilities</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="140">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="587.0">
#     <tspan class="displacy-word" fill="currentColor" x="230">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="230">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="587.0">
#     <tspan class="displacy-word" fill="currentColor" x="320">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="320">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="587.0">
#     <tspan class="displacy-word" fill="currentColor" x="410">Division</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="410">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="587.0">
#     <tspan class="displacy-word" fill="currentColor" x="500">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="500">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="587.0">
#     <tspan class="displacy-word" fill="currentColor" x="590">Public</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="590">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="587.0">
#     <tspan class="displacy-word" fill="currentColor" x="680">Health</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="680">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="587.0">
#     <tspan class="displacy-word" fill="currentColor" x="770">'s</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="770">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="587.0">
#     <tspan class="displacy-word" fill="currentColor" x="860">representative</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="860">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="587.0">
#     <tspan class="displacy-word" fill="currentColor" x="950">include:</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="950">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="587.0">
#     <tspan class="displacy-word" fill="currentColor" x="1040">serving</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1040">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="587.0">
#     <tspan class="displacy-word" fill="currentColor" x="1130">as</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1130">SCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="587.0">
#     <tspan class="displacy-word" fill="currentColor" x="1220">staff</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1220">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="587.0">
#     <tspan class="displacy-word" fill="currentColor" x="1310">person</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1310">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="587.0">
#     <tspan class="displacy-word" fill="currentColor" x="1400">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1400">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="587.0">
#     <tspan class="displacy-word" fill="currentColor" x="1490">recording</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1490">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="587.0">
#     <tspan class="displacy-word" fill="currentColor" x="1580">secretary</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1580">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="587.0">
#     <tspan class="displacy-word" fill="currentColor" x="1670">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1670">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="587.0">
#     <tspan class="displacy-word" fill="currentColor" x="1760">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1760">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="587.0">
#     <tspan class="displacy-word" fill="currentColor" x="1850">Commission,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1850">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="587.0">
#     <tspan class="displacy-word" fill="currentColor" x="1940">informing</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1940">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="587.0">
#     <tspan class="displacy-word" fill="currentColor" x="2030">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2030">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="587.0">
#     <tspan class="displacy-word" fill="currentColor" x="2120">Commission</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2120">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="587.0">
#     <tspan class="displacy-word" fill="currentColor" x="2210">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2210">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="587.0">
#     <tspan class="displacy-word" fill="currentColor" x="2300">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2300">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="587.0">
#     <tspan class="displacy-word" fill="currentColor" x="2390">progress</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2390">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="587.0">
#     <tspan class="displacy-word" fill="currentColor" x="2480">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2480">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="587.0">
#     <tspan class="displacy-word" fill="currentColor" x="2570">conditions</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2570">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="587.0">
#     <tspan class="displacy-word" fill="currentColor" x="2660">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2660">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="587.0">
#     <tspan class="displacy-word" fill="currentColor" x="2750">the</tspan>
#     <tspan class="displacy-tag"
